# %% [markdown]
# # Print:
#      - Print is python function that prints the given valid value on the console.

# %%
print("Hello Python World!")
# Out:
# Hello Python World!

# %% [markdown]
# # Value : Data
#       - text   : String  : "anything under quotes"
#       - number : int, float : 23, 45.78
#       - boolean: bool       : True , False

# %%
print(23)
# Out:
# 23

# %%
print(5.7)
# Out:
# 5.7

# %%
print(False)
# Out:
# False

# %%
print(45.56)
# Out:
# 45.56

# %%
print("Where are you")
# Out:
# Where are you

# %% [markdown]
# # Operators
#    - Aithmetic Operators
#    - Boolean Operators
#    - Logical Operators

# %% [markdown]
# # Arithmetic Operators:
#   - add(+)
#   - sub(-)
#   - mul(*)
#   - div(/, //)

# %%
print(4 + 6 )
# Out:
# 10

# %%
print(6-2)
# Out:
# 4

# %%
print(4*5)
# Out:
# 20

# %%
print(12/4)
# Out:
# 3.0

# %%
print(12//5)
# Out:
# 2

# %% [markdown]
# # Special Operators:
#   - assignment operator  (=)
#   - modulo operator      (%)
#   - exponent             (**)
#   - in
#   - is

# %%
language = 'Python'

# %%
print(language)
# Out:
# Python

# %%
13 %  5
# Out:
# 3

# %%
2**3
# Out:
# 8

# %%
3**3
# Out:
# 27

# %% [markdown]
# # Boolean / Comparision Operators
#   - equal to   (==)
#   - not equal to (!=)
#   - greater than (>)
#   - less than (<)
#   - greater than equal to (>=)
#   - less than equal to  (<=)
#   -

# %%
asif = 23
arham = 10
taham = 23

# %%
arham > asif
# Out:
# False

# %%
arham < asif
# Out:
# True

# %%
taham == asif
# Out:
# True

# %%
taham>=asif
# Out:
# True

# %%
ayub = 16

# %%
ayub <> arham
# Out:
#   Cell In[29], line 1
#     ayub <> arham
#          ^
# SyntaxError: invalid syntax

# %%
10/3 == 3.3
# Out:
# False

# %%
10/3
# Out:
# 3.3333333333333335

# %% [markdown]
# # Logical Operators:
#     - and
#     - or
#
#
# Exp1    and    Exp2       Result
#  True           True         True
#  True           False        False
#  False          True         False
#  False          False        False
#
#
# Exp1    OR    Exp2       Result
#  True          True        True
#  True          False       True
#  False         True        True
#  False         False       False

# %%
12>3 or 13>1 or 15<10
# Out:
# True

# %%
12>3 and 3>1 and 15<10
# Out:
# False

# %%
marks = 56.5

# %%
type(marks)
# Out:
# float

# %%
isinstance(marks,int)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool("apple")
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool([23,3]), bool([])
# Out:
# (True, False)

# %%
a = 1000
b = ''
c= 300
a or b or c
# Out:
# 1000

# %%
x = -100
from math import sqrt
x > 0 or sqrt(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 3
#       1 x = -100
#       2 from math import sqrt
# ----> 3 x > 0 or sqrt(x)
#
# ValueError: math domain error

# %% [markdown]
# https://realpython.com/quizzes/python-operators-expressions/
