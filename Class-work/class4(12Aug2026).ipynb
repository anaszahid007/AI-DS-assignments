# %% [markdown]
# # Logical Operator:
#      - or
#      - and

# %%
not(True)
# Out:
# False

# %%
not(False)
# Out:
# True

# %% [markdown]
# # User Inputs:
#    we can take input values from user. using input function.

# %%
name = input("Please tell me you r good name?")
age  = int(input("Tell me your age?"))
# Out:
# Please tell me you r good name? salma
# Tell me your age? 22

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
age + 1
# Out:
# 23

# %% [markdown]
# # String:
#   - string is a python data structure. (python class)
#   - it has many buitin functionalities.
#   - string is immutable.

# %%
country = input("Where are you from?")
# Out:
# Where are you from? i am from pakistan. now adays living in dubai

# %%
type(country)
# Out:
# str

# %%
country.capitalize()
# Out:
# 'I am from pakistan. now adays living in dubai'

# %%
country.title()
# Out:
# 'I Am From Pakistan. Now Adays Living In Dubai'

# %%
country
# Out:
# 'china'

# %%
country.lower()
# Out:
# 'china'

# %%
country.upper()
# Out:
# 'CHINA'

# %%
country.count('a')
# Out:
# 6

# %%
country.count('A')
# Out:
# 0

# %%
country.endswith('i')
# Out:
# True

# %%
country.startswith('i')
# Out:
# True

# %%
country = input("Where are you from?")
# Out:
# Where are you from? pakistan

# %%
country.find('a',2)
# Out:
# 6

# %%
country.find('A')
# Out:
# -1

# %%
country.index('A')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 country.index('A')
#
# ValueError: substring not found

# %%
"oneapple".isalpha()
# Out:
# True

# %%
"13 ".isdigit()
# Out:
# False

# %%
"15".isdecimal()  # ye decimal number system wala decimal chekc karata hy
# Out:
# True

# %%
bin(45)
# Out:
# '0b101101'

# %%
"0bc".isdecimal()
# Out:
# False

# %%
"101101".isdecimal()
# Out:
# True

# %%
binary_string = "100"
decimal_number = int(binary_string, 2)
decimal_number
# Out:
# 4

# %%
"were.".islower()
# Out:
# True

# %%
"WERE".isupper()
# Out:
# True

# %%
"we123".islower()
# Out:
# True

# %% [markdown]
# # string concatenate: join

# %%
name = "salma"
abba_name = 'saleem'

# %%
name + abba_name
# Out:
# 'salmasaleem'

# %%
name = input("Please tell me you r good name?")
age  = int(input("Tell me your age?"))
country = input("Where are you from?")
# Out:
# Please tell me you r good name? Salma
# Tell me your age? 42
# Where are you from? London

# %% [markdown]
# "Salma is my new friend. She is 42 years old living in London "

# %%
name+"is my new friend. She is"+age+"years old living in"+country
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 name+"is my new friend. She is"+age+"years old living in"+country
#
# TypeError: can only concatenate str (not "int") to str

# %%
name+"is my new friend. She is"+str(age)+"years old living in"+country
# Out:
# 'Salmais my new friend. She is42years old living inLondon'

# %%
name+" is my new friend. She is "+str(age)+" years old living in "+country
# Out:
# 'Salma is my new friend. She is 42 years old living in London'

# %%
"{} is my new friend. She is {} years old living in {}".format(name,age,country)
# Out:
# 'Salma is my new friend. She is 42 years old living in London'

# %% [markdown]
# # f-string

# %%
f"{name} is my new friend. She is {age} years old living in {country}"
# Out:
# 'Salma is my new friend. She is 42 years old living in London'

# %%
f"{name} is my new friend. She is {age} years old living in {country}"
# Out:
# 'Salma is my new friend. She is 42 years old living in London'
