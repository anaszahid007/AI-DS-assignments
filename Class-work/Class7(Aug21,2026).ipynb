# %% [markdown]
# # Todays Topics
#   - Revision
#   - Conditional statements
#     - if statement
#     - if else statement
#     - elif statement
#
#     - Nested if Condition/ Statements

# %%
Students = {'Name':'Usman','FatherName':'Saad','age':20,'Class':'Undergraduate','University': 'NED'}

# %%
Students
# Out:
# {'Name': 'Usman',
#  'FatherName': 'Saad',
#  'age': 20,
#  'Class': 'Undergraduate',
#  'University': 'NED'}

# %%
Students['Name'] ='jameel'

# %%
Students
# Out:
# {'Name': 'jameel',
#  'FatherName': 'Saad',
#  'age': 20,
#  'Class': 'Undergraduate',
#  'University': 'NED'}

# %%
Mytuple= ('Ali',21,'karachi')

# %%
myfav = ('biryani','pizza','7up zero')

# %%
Mytuple + myfav
# Out:
# ('Ali', 21, 'karachi', 'biryani', 'pizza', '7up zero')

# %%
Mytuple[2]
# Out:
# 'karachi'

# %% [markdown]
# # Conditional statement

# %% [markdown]
# if (condition)-> true
#   ------------------
#   -----------------

# %%
if True:
  print("hz")
# Out:
# hz

# %%
if True:
  print("hz")
# Out:
#   File "/tmp/ipykernel_697/1525868982.py", line 2
#     print("hz")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
name = input("what is your name ?")
if name == 'Usman':
  print("the person is authentic")
else:
  print("The person is not Authentic")
# Out:
# what is your name ?Usman
# the person is authentic

# %% [markdown]
# #### Discount Orirented Program Using IF & ELSE

# %%
BillAmount = float(input("Kindly Enter your Bill Amount :"))
if BillAmount >= 20000.0 :
  discount = BillAmount * 0.20
  print(f"Your discount in RS:{discount} on the purchase of RS:{BillAmount}")
else:
  print(f"you have Purchased amount is {BillAmount}, so you cant avail the Discount Offer")
# Out:
# Kindly Enter your Bill Amount :50000
# Your discount in RS:10000.0 on the purchase of RS:50000.0

# %%
print(f"you have Purchased amount is {BillAmount}, so you cant avail the Discount Offer   ")
# Out:
# you have Purchased amount is 50000.0, so you cant avail the Discount Offer    50000.0

# %% [markdown]
# ### elif Statements use

# %%
BillAmount = float(input("Kindly Enter your Bill Amount :"))
if BillAmount >= 20000.0 :
  discount = BillAmount * 0.20
  print(f"Your discount in RS:{discount} on the purchase of RS:{BillAmount}")

else:
  print(f"you have Purchased amount is {BillAmount}, so you cant avail the Discount Offer")

# %%
age = int(input("what is yout age: "))
if age >= 18:
  print("business can be done")
elif age < 18 and age >= 12:
  print("you need to learn how to run business")
else:
  print("just do what you want")
# Out:
# what is yout age: 50
# business can be done

# %%
Myname = "furqan"
yname = "Usman"
if Myname == "Ali":
  print("not hanzala")
elif Myname == "furqan":
  print("ya bhi hanzala nahi hn")
  if yname == 'Usman':
    print("ya usman hn")
else:
  print("ya hanzala he hn")
# Out:
# ya bhi hanzala nahi hn
# ya usman hn
