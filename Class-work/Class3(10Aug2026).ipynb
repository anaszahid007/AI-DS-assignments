# %% [markdown]
# # Revision Work
#     - printing values
#     - data types
#     - operators
#     - variables

# %%
print(12)
# Out:
# 12

# %%
print(34,3,56,89)
# Out:
# 34 3 56 89

# %%
print("Hello Python")
# Out:
# Hello Python

# %%
print("50")
# Out:
# 50

# %%
print(67.8)
# Out:
# 67.8

# %%
print("Python", "Java", sep=",",end="")
print("We are learning Python")
# Out:
# Python,JavaWe are learning Python

# %% [raw]
# Nasir
# Hussain
# Asad
# Farhan
# Ali

# %%
print('Nasir')
print('Hussain')
print('Asad')
print('Ali')
# Out:
# Nasir
# Hussain
# Asad
# Ali

# %%
print('Nasir','Hussain','Asad', 'Ali', sep="\n")
# Out:
# Nasir
# Hussain
# Asad
# Ali

# %% [markdown]
# # Data Types
#     - Numbers
#        - Integers   1,2,3,4
#        - Floats     5.6, 7.5
#     - Text(String)
#           - "String", 'String', """String""", '''String'''
#     - bool(boolean) True / False

# %%
print(100)
# Out:
# 100

# %%
print(56.8)
# Out:
# 56.8

# %%
print("hi")
# Out:
# hi

# %%
print(True)
# Out:
# True

# %%
type(100), type(34.6), type('pak'),type(False)
# Out:
# (int, float, str, bool)

# %% [markdown]
# # Variables: are containers (dabba) that hold values

# %%
name = 'asad'

# %%
print(name)
# Out:
# asad

# %%
id(name)
# Out:
# 2033346462032

# %%
name  = "shahzada"

# %%
print(name)
# Out:
# shahzada

# %%
id(name)
# Out:
# 2033346867824

# %%
marks  = 100

# %%
print(marks + 45)
# Out:
# 145

# %%
marks
# Out:
# 100

# %% [markdown]
# Python is a high-level, general-purpose programming language that emphasizes code readability, simplicity, and ease-of-writing with the use of significant indentation,[38] an extensive ("batteries-included") standard library, and garbage collection. Python supports multiple programming paradigms but with an emphasis on object-oriented programming and dynamic typing.
#
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language. Python 3.0, released in 2008, was a major revision and not completely backward-compatible with earlier versions.

# %%
language = "Python"
level = 'high'
purpose = 'general purpose programming'
inventor = 'Guido van Rossum'
year = 1980
latest_version = 3
release_v3 = 2008

# %% [markdown]
# # Variable Naming Conventions:
#   - choose a variable name that truley defines the value inside.
#       a = 22  wrong
#       age = 22 Right
#  - variable should not be a python rserve word
#    ![image.png](attachment:d2bc4381-40ec-4242-8d61-306fc06e3e22.png)
#  - start should not be a number:
#         1ststudent  wrong
#         student1    right
#  - special chractrs nahi asakte:
#         !@#$%^&*()<>{}
#  - space nahi asakta
#     father name :  wrong
#     father_name : right

# %%
myfirstbookonprogramming="Python for Kids"

# %%
MyFirstBookOnProgramming = "Python for Kids"

# %%
my_first_book_on_programming = "Python for Kids"

# %%
myFirstBookonProgramming = "Python for Kids"

# %%
MYFIRSTBOOK ="Python for Kids"

# %%
global = 12
# Out:
#   Cell In[44], line 1
#     global = 12
#            ^
# SyntaxError: invalid syntax

# %%
lambda = 2
# Out:
#   Cell In[45], line 1
#     lambda = 2
#            ^
# SyntaxError: invalid syntax

# %%
Lambda = 2

# %% [markdown]
# # Operators
#    - Arithmetic Operators

# %%
num1 = 200
num2  = 100

# %%
ans = num1 + num2

# %%
print(ans)
ans
# Out:
# 300
# 300

# %%
name
# Out:
# 'shahzada'

# %%
print(name)
# Out:
# shahzada

# %%
result = 51 + 4 - 3 ** 3 // 19 - 3
print(result)
# Out:
# 51

# %%
"apple" *5
# Out:
# 'appleappleappleappleapple'

# %%
print(2 * 2 ** 2 * 2)
# Out:
# 16

# %%
x = 100
y = 50
print(x and y)
# Out:
# 50

# %%
print(10 > 5 and "hello" == "world")
# Out:
# False

# %%
print(2 ** 3 ** 2)
# Out:
# 512

# %%
8 / 2 + 2 * 3
# Out:
# 10.0

# %%
10 > 5 < 2
# Out:
# False

# %%
3 * "Hello"
# Out:
# 'HelloHelloHello'

# %%
-5 // 2
# Out:
# -3

# %%
8 % 3 + 2 ** 2 * (2 + 2)
#   8%3 + 2** 2  *    4
#   8%3 +4*4
#   2 + 16
# 18
# Out:
# 18

# %%
round(2.564, 3)
# Out:
# 2.564

# %% [markdown]
# # Type Casting : type changing

# %%
marks  = '100'

# %%
type(marks)
# Out:
# str

# %%
marks - 45
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 marks - 45
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
int(marks)
# Out:
# 100

# %%
marks = int(marks)

# %%
type(marks)
# Out:
# int

# %%
percentage = "56.8"

# %%
int(percentage)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 int(percentage)
#
# ValueError: invalid literal for int() with base 10: '56.8'

# %%
int(float(percentage))
# Out:
# 56

# %%
age  = 'twelwe'

# %%
int(age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 int(age)
#
# ValueError: invalid literal for int() with base 10: 'twelwe'
